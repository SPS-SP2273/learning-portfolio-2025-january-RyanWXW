# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ### TASK 1

# %%
import glob
import os 
import shutil

# %%
month_dict = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

filename = 'oct-08_singapore.txt'
parts = filename.split('-')
month = parts[0]
rest = '-'.join(parts[1:]) 

new_filename = month_dict[month] + '-' + rest

print(new_filename)
# Out:
# 10-08_singapore.txt

# %%
month_dict = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

filename = 'oct-08_singapore.txt'
parts = filename.split('-')
month = parts[0]
rest = parts[1]  
date_city = rest.replace('_', '-')  

new_filename = month_dict[month] + '-' + date_city

print(new_filename)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ### TASK 2

# %%
def rename_my_file(old_file_name):

    month_dict = {
        'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'
    }

    parts = old_file_name.split('-')
    month = parts[0]
    rest = parts[1]
    date_city = rest.replace('_', '-')

    new_filename = month_dict[month] + '-' + date_city

    return new_filename

# %%
old_filename = 'oct-08_singapore.txt'
new_filename = rename_my_file(old_filename)
print(f"Old filename: {old_filename}")
print(f"New filename: {new_filename}")
# Out:
# Original filename: oct-08_singapore.txt
# Renamed filename: 10-08-singapore.txt

# %% [markdown]
# ### TASK 3

# %%
file_list = [
    'oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
    'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
    'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
    'jan-01_tokyo.txt'
]

for old_filename in file_list:
    new_filename = rename_my_file(old_filename)
    print(f"{old_filename} ----> {new_filename}")
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ### TASK 4

# %%
xt_files = glob.glob("*.txt")

# %%
txt_files = glob.glob("os-collaboration-exercise-data/*.txt")

# %%
glob.glob("os-collaboration-exercise-data/*.txt")
# Out:
# ['os-collaboration-exercise-data/dec-10_osaka.txt',
#  'os-collaboration-exercise-data/jul-14_karachi.txt',
#  'os-collaboration-exercise-data/nov-17_osaka.txt',
#  'os-collaboration-exercise-data/jul-13_cairo.txt',
#  'os-collaboration-exercise-data/jun-15_manila.txt',
#  'os-collaboration-exercise-data/aug-20_tokyo.txt',
#  'os-collaboration-exercise-data/jun-16_melbourne.txt',
#  'os-collaboration-exercise-data/sep-05_tokyo.txt',
#  'os-collaboration-exercise-data/jun-22_manila.txt',
#  'os-collaboration-exercise-data/apr-11_shanghai.txt',
#  'os-collaboration-exercise-data/sep-21_singapore.txt',
#  'os-collaboration-exercise-data/feb-01_singapore.txt',
#  'os-collaboration-exercise-data/may-09_manila.txt',
#  'os-collaboration-exercise-data/jan-20_tokyo.txt',
#  'os-collaboration-exercise-data/jan-30_manila.txt',
#  'os-collaboration-exercise-data/jun-28_tokyo.txt',
#  'os-collaboration-exercise-data/apr-16_shanghai.txt',
#  'os-collaboration-exercise-data/dec-07_shanghai.txt',
# ...

# %%
import glob
import os 
import shutil

for old_filename in txt_files:
    new_filename = rename_my_file(old_filename)
    os.rename(old_filename, new_filename)  

    print(f"{old_filename} ----> {new_filename}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 6
#       3 import shutil
#       5 for old_filename in txt_files:
# ----> 6     new_filename = rename_my_file(old_filename)
#       7     os.rename(old_filename, new_filename)
#       9     print(f"{old_filename} ----> {new_filename}")
#
# Cell In[14], line 24, in rename_my_file(old_file_name)
#      21 rest = parts[1]
#      22 date_city = rest.replace('_', '-')
# ---> 24 new_filename = month_dict[month] + '-' + date_city
#      26 return new_filename
#
# KeyError: 'os'

# %%
parts = old_filename.split('/')
osfoldername = parts[0]
txtfile = parts[1]
    
new_filename = osfoldername + '/' + rename_my_file(txtfile)

# %%
glob.glob("os-collaboration-exercise-data/*.txt")
# Out:
# ['os-collaboration-exercise-data/dec-10_osaka.txt',
#  'os-collaboration-exercise-data/jul-14_karachi.txt',
#  'os-collaboration-exercise-data/nov-17_osaka.txt',
#  'os-collaboration-exercise-data/jul-13_cairo.txt',
#  'os-collaboration-exercise-data/jun-15_manila.txt',
#  'os-collaboration-exercise-data/aug-20_tokyo.txt',
#  'os-collaboration-exercise-data/jun-16_melbourne.txt',
#  'os-collaboration-exercise-data/sep-05_tokyo.txt',
#  'os-collaboration-exercise-data/jun-22_manila.txt',
#  'os-collaboration-exercise-data/apr-11_shanghai.txt',
#  'os-collaboration-exercise-data/sep-21_singapore.txt',
#  'os-collaboration-exercise-data/feb-01_singapore.txt',
#  'os-collaboration-exercise-data/may-09_manila.txt',
#  'os-collaboration-exercise-data/jan-20_tokyo.txt',
#  'os-collaboration-exercise-data/jan-30_manila.txt',
#  'os-collaboration-exercise-data/jun-28_tokyo.txt',
#  'os-collaboration-exercise-data/apr-16_shanghai.txt',
#  'os-collaboration-exercise-data/dec-07_shanghai.txt',
# ...

# %%
import glob
import os 
import shutil

txt_files = glob.glob("os-collaboration-exercise-data/*.txt")
for old_filename in txt_files:
    parts = old_filename.split('/')
    osfoldername = parts[0]
    txtfile = parts[1]
    new_filename = osfoldername + '/' + rename_my_file(txtfile)

    print(f"{old_filename} ----> {new_filename}")
# Out:
# os-collaboration-exercise-data/dec-10_osaka.txt ----> os-collaboration-exercise-data/12-10-osaka.txt
# os-collaboration-exercise-data/jul-14_karachi.txt ----> os-collaboration-exercise-data/07-14-karachi.txt
# os-collaboration-exercise-data/nov-17_osaka.txt ----> os-collaboration-exercise-data/11-17-osaka.txt
# os-collaboration-exercise-data/jul-13_cairo.txt ----> os-collaboration-exercise-data/07-13-cairo.txt
# os-collaboration-exercise-data/jun-15_manila.txt ----> os-collaboration-exercise-data/06-15-manila.txt
# os-collaboration-exercise-data/aug-20_tokyo.txt ----> os-collaboration-exercise-data/08-20-tokyo.txt
# os-collaboration-exercise-data/jun-16_melbourne.txt ----> os-collaboration-exercise-data/06-16-melbourne.txt
# os-collaboration-exercise-data/sep-05_tokyo.txt ----> os-collaboration-exercise-data/09-05-tokyo.txt
# os-collaboration-exercise-data/jun-22_manila.txt ----> os-collaboration-exercise-data/06-22-manila.txt
# ...

# %% [markdown]
# ### TASK 5

# %%
os.mkdir('city')

for cities in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    path = os.path.join('city', cities)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating city/Cairo
# Creating city/Dhaka
# Creating city/Jakarta
# Creating city/Karachi
# Creating city/Manila
# Creating city/Melbourne
# Creating city/Osaka
# Creating city/Shanghai
# Creating city/Singapore
# Creating city/Tokyo

# %% [markdown]
# ### TASK 6

# %%
cairo_files = glob.glob('os-collaboration-exercise-data/*_cairo.txt')

if not os.path.exists('Cairo'):
    os.makedirs('Cairo')

for old_file_path in cairo_files:
    old_file_name = os.path.basename(old_file_path)
    new_file_name = rename_my_file(old_file_name)
    new_file_path = os.path.join('Cairo', new_file_name)
    shutil.copy(old_file_path, new_file_path)
    print(f"{old_file_name} ----> {new_file_name}")
# Out:
# jul-13_cairo.txt ----> 07-13-cairo.txt
# dec-27_cairo.txt ----> 12-27-cairo.txt
# jul-26_cairo.txt ----> 07-26-cairo.txt
# may-30_cairo.txt ----> 05-30-cairo.txt
# jan-13_cairo.txt ----> 01-13-cairo.txt
# feb-26_cairo.txt ----> 02-26-cairo.txt
# aug-07_cairo.txt ----> 08-07-cairo.txt
# sep-22_cairo.txt ----> 09-22-cairo.txt
# jan-07_cairo.txt ----> 01-07-cairo.txt
# aug-26_cairo.txt ----> 08-26-cairo.txt
# apr-24_cairo.txt ----> 04-24-cairo.txt
# may-29_cairo.txt ----> 05-29-cairo.txt
# dec-21_cairo.txt ----> 12-21-cairo.txt
# sep-08_cairo.txt ----> 09-08-cairo.txt
# aug-18_cairo.txt ----> 08-18-cairo.txt
# may-17_cairo.txt ----> 05-17-cairo.txt
# jul-15_cairo.txt ----> 07-15-cairo.txt
# jun-28_cairo.txt ----> 06-28-cairo.txt
# jan-20_cairo.txt ----> 01-20-cairo.txt
# aug-20_cairo.txt ----> 08-20-cairo.txt
# sep-05_cairo.txt ----> 09-05-cairo.txt
# apr-22_cairo.txt ----> 04-22-cairo.txt
# sep-11_cairo.txt ----> 09-11-cairo.txt
# feb-20_cairo.txt ----> 02-20-cairo.txt
# ...

# %% [markdown]
# ### TASK 7

# %%
cities = ["Cairo", "Dhaka", "Jakarta", "Karachi", "Manila", "Melbourne", "Osaka", "Shanghai", "Singapore", "Tokyo"]

for city in cities:
    if not os.path.exists(city):
        os.makedirs(city)

files = glob.glob('os-collaboration-exercise-data/*.txt')

for old_file_path in files:
    old_file_name = os.path.basename(old_file_path)
    new_file_name = rename_my_file(old_file_name)  
    city = new_file_name.split('-')[2].split('.')[0].capitalize() 
    new_file_path = os.path.join(city, new_file_name)

    shutil.move(old_file_path, new_file_path)
    print(f"{old_file_name} ----> {new_file_name}")
